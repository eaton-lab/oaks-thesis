# %%
import ipyrad as ip
import ipyrad.analysis as ipa
import toytree
import toyplot

# %% [markdown]
# Run tetrad with more quartets, potentially other parameter changes.

# %%
data = "/moto/eaton/users/hnl2109/analysis-ipyrad/robur_ref_basic_outfiles/robur_ref_basic.snps.hdf5"

tet01 = ipa.tetrad(
    name="robur-ref-2e6-quartets",
    workdir="/moto/eaton/users/hnl2109/analysis-tetrad/",
    data=data,
    nquartets=2e6,
    nboots=16,
)
# Out:
# loading snps array [261 taxa x 2253184 snps]
# max unlinked SNPs per quartet [nloci]: 167724
# quartet sampler [random]: 2000000 / 188939205

# %%
tet01.run(force = True, auto = True)
# Out:
# Parallel connection | t103: 24 cores
# initializing quartet sets database
# [####################] 100% 0:34:13 | full tree * | avg SNPs/qrt: 7606
# [####################] 100% 0:34:45 | boot rep. 1 | avg SNPs/qrt: 7817
# [####################] 100% 0:35:02 | boot rep. 2 | avg SNPs/qrt: 7920
# [####################] 100% 0:34:48 | boot rep. 3 | avg SNPs/qrt: 7645
# [####################] 100% 0:34:41 | boot rep. 4 | avg SNPs/qrt: 7432
# [####################] 100% 0:34:55 | boot rep. 5 | avg SNPs/qrt: 7521
# [####################] 100% 0:34:27 | boot rep. 6 | avg SNPs/qrt: 7674
# [####################] 100% 0:34:08 | boot rep. 7 | avg SNPs/qrt: 7606
# [####################] 100% 0:34:15 | boot rep. 8 | avg SNPs/qrt: 7697
# [####################] 100% 0:34:34 | boot rep. 9 | avg SNPs/qrt: 7661
# [####################] 100% 0:34:26 | boot rep. 11 | avg SNPs/qrt: 7665
# [####################] 100% 0:34:57 | boot rep. 12 | avg SNPs/qrt: 7584
# [####################] 100% 0:33:58 | boot rep. 13 | avg SNPs/qrt: 7597
# [####################] 100% 0:34:59 | boot rep. 14 | avg SNPs/qrt: 7678
# [####################] 100% 0:34:29 | boot rep. 15 | avg SNPs/qrt: 7460
# [####################] 100% 0:34:33 | boot rep. 16 | avg SNPs/qrt: 7595

# %%
tre01 = toytree.tree("/moto/eaton/users/hnl2109/analysis-tetrad/robur-ref-2e6-quartets.tree")
tre01.draw(width = 500, height = 3000, node_labels="support", use_edge_lengths=False);
# Out:
# <div class="toyplot" id="tf531f364933d474994a3ffae12da1589" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="3000.0px" id="teb8665b67f344832accf889a5d129c6e" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 3000.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t5a8aff460dad4791aa4410fe9d920ec8"><clipPath id="ta187cb604a234dbbad1b537bc8b6dc8d"><rect height="2940.0" width="440.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#ta187cb604a234dbbad1b537bc8b6dc8d)"><g class="toytree-mark-Toytree" id="tcb85faa562214d0d96eae736ec923ff9"><g class="toytree-Edges" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"><path d="M 50.0 704.3 L 50.0 69.9 L 272.2 69.9" id="517,516"></path><path d="M 50.0 704.3 L 50.0 197.6 L 61.1 197.6" id="517,515"></path><path d="M 50.0 704.3 L 50.0 1845.5 L 72.2 1845.5" id="517,514"></path><path d="M 272.2 69.9 L 272.2 80.3 L 283.3 80.3" id="516,513"></path><path d="M 61.1 197.6 L 61.1 120.5 L 305.6 120.5" id="515,512"></path><path d="M 61.1 