# %%
import toyplot
import toytree

# %%
rtre05c = toytree.tree("/moto/eaton/users/hnl2109/newick-calib-trees/newick-cal-crown_basic_scaffold05.tree")
canvas05c, axes05c, mark05c = rtre05c.draw(
    height=2000,
    scalebar=True,
    tip_labels_style={"font-size": "8px"},
    edge_colors=rtre05c.get_edge_values_mapped({
        rtre05c.get_mrca_idx_from_tip_labels(wildcard = "Q."),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Quercus|Lobatae|Agrifoliae|Q.agrifolia',
                                                 'Quercus|Lobatae|Erythromexicana|Q.emoryi']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['SRR5984311',
                                                     'Cerris|Cyclobalanopsis|Acuta|Q.acuta']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Quercus|Quercus|Dumosae|Q.lobata',
                                                 'Quercus|Quercus|Leucomexicana|Q.arizonica']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Cerris|Ilex|Early-divergingIlex|Q.franchetii',
                                                 'Cerris|Ilex|Himalayansubalpine|Q.gujavifolia']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Cerris|Ilex|Himalayansubalpine|Q.gujavifolia',
                                                 'Cerris|Ilex|Himalayansubalpine|Q.semecarpifolia']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Cerris|Cerris|EastAsianCerris|Q.chenii',
                                                 'Cerris|Cerris|EastAsianCerris|Q.acutissima']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Cerris|Cerris|WestEurasianCerris|Q.crenata',
                                                 'Cerris|Cerris|WestEurasianCerris|Q.cerris']),
    }),
)
# Out:
# <div class="toyplot" id="td4e85e89654d48a69715373ec89fd86f" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="2000.0px" id="t70d76204c4994cfa9fb4281fdfab6325" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 2000.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tdd6526acda8b4150a20003688e69d98e"><clipPath id="t1eb6183bcbde42f3b7cd6b0c350f3939"><rect height="1940.0" width="440.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t1eb6183bcbde42f3b7cd6b0c350f3939)"><g class="toytree-mark-Toytree" id="tacbdabdaacf043ce88d44fae3dfa465d"><g class="toytree-Edges" style="fill:
# ...

# %%
canvas05c, axes05c, mark05c = rtre05c.draw(
    layout="c",
    height=1000,
    scalebar=True,
    tip_labels=False,
    edge_colors=rtre05c.get_edge_values_mapped({
        rtre05c.get_mrca_idx_from_tip_labels(wildcard = "Q."),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Quercus|Lobatae|Agrifoliae|Q.agrifolia',
                                                 'Quercus|Lobatae|Erythromexicana|Q.emoryi']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['SRR5984311',
                                                     'Cerris|Cyclobalanopsis|Acuta|Q.acuta']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Quercus|Quercus|Dumosae|Q.lobata',
                                                 'Quercus|Quercus|Leucomexicana|Q.arizonica']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Cerris|Ilex|Early-divergingIlex|Q.franchetii',
                                                 'Cerris|Ilex|Himalayansubalpine|Q.gujavifolia']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Cerris|Ilex|Himalayansubalpine|Q.gujavifolia',
                                                 'Cerris|Ilex|Himalayansubalpine|Q.semecarpifolia']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Cerris|Cerris|EastAsianCerris|Q.chenii',
                                                 'Cerris|Cerris|EastAsianCerris|Q.acutissima']),
        rtre05c.get_mrca_idx_from_tip_labels(names = ['Cerris|Cerris|WestEurasianCerris|Q.crenata',
                                                 'Cerris|Cerris|WestEurasianCerris|Q.cerris']),
    }),
)
# Out:
# <div class="toyplot" id="t2d70b29dfa3b4d758478da694bd0fb8b" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="1000.0px" id="t3b72f3a764b04b9bbda630ea9cd33ab1" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 1000.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t689f239b18854b0284dd25b2099498ef"><clipPath id="teb1ccfdbd82445fea4d2d87b976928be"><rect height="940.0" width="940.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#teb1ccfdbd82445fea4d2d87b976928be)"><g class="toytree-mark-Toytree" id="tabf2969be7504df0a328f1513dc80e99"><g class="toytree-Edges" style="fill
# ...

# %%
rtre05s = toytree.tree("/moto/eaton/users/hnl2109/newick-calib-trees/newick-cal-stem_basic_scaffold05.tree")
canvas05s, axes05s, mark05s = rtre05s.draw(
    height=2000,
    scalebar=True,
    tip_labels_style={"font-size": "8px"},
    edge_colors=rtre05s.get_edge_values_mapped({
        rtre05s.get_mrca_idx_from_tip_labels(wildcard="Cerris|"),
        rtre05s.get_mrca_idx_from_tip_labels(wildcard="Lobatae|"),
        rtre05s.get_mrca_idx_from_tip_labels(wildcard="Roburoids|"),
        rtre05s.get_mrca_idx_from_tip_labels(wildcard="Virentes|"),
        rtre05s.get_mrca_idx_from_tip_labels(wildcard="Protoba"),
        rtre05s.get_mrca_idx_from_tip_labels(wildcard="Leuco"),
        rtre05s.get_mrca_idx_from_tip_labels(wildcard="Ponticae|"),
    }),
)
# Out:
# <div class="toyplot" id="t31a4035692da44f481fc6998d42cb73f" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="2000.0px" id="t1c81d22e33b14ee58adea3445881d85b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 2000.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tcd17d9f24bbb43329545bb7ca603b282"><clipPath id="tf89f75f5eca644a1864e26a6bfb28dc1"><rect height="1940.0" width="440.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#tf89f75f5eca644a1864e26a6bfb28dc1)"><g class="toytree-mark-Toytree" id="t44e11730c19a410f946e3dd11b5e0d58"><g class="toytree-Edges" style="fill:
# ...

# %%
tre05_l0 = toytree.tree("/moto/eaton/users/hnl2109/newick-calib-trees/newick-cal-crown-lambda0_basic_scaffold05.tree")
canvas05_l0, axes05_l0, mark05_l0 = tre05_l0.draw(
    height=2000,
    scalebar=True,
    tip_labels_style={"font-size": "8px"},
    edge_colors=tre05_l0.get_edge_values_mapped({
        tre05_l0.get_mrca_idx_from_tip_labels(wildcard = "Q."),
        tre05_l0.get_mrca_idx_from_tip_labels(names = ['Quercus|Lobatae|Agrifoliae|Q.agrifolia',
                                                 'Quercus|Lobatae|Erythromexicana|Q.emoryi']),
        tre05_l0.get_mrca_idx_from_tip_labels(names = ['SRR5984311',
                                                     'Cerris|Cyclobalanopsis|Acuta|Q.acuta']),
        tre05_l0.get_mrca_idx_from_tip_labels(names = ['Quercus|Quercus|Dumosae|Q.lobata',
                                                 'Quercus|Quercus|Leucomexicana|Q.arizonica']),
        tre05_l0.get_mrca_idx_from_tip_labels(names = ['Cerris|Ilex|Early-divergingIlex|Q.franchetii',
                                                 'Cerris|Ilex|Himalayansubalpine|Q.gujavifolia']),
        tre05_l0.get_mrca_idx_from_tip_labels(names = ['Cerris|Ilex|Himalayansubalpine|Q.gujavifolia',
                                                 'Cerris|Ilex|Himalayansubalpine|Q.semecarpifolia']),
        tre05_l0.get_mrca_idx_from_tip_labels(names = ['Cerris|Cerris|EastAsianCerris|Q.chenii',
                                                 'Cerris|Cerris|EastAsianCerris|Q.acutissima']),
        tre05_l0.get_mrca_idx_from_tip_labels(names = ['Cerris|Cerris|WestEurasianCerris|Q.crenata',
                                                 'Cerris|Cerris|WestEurasianCerris|Q.cerris']),
    }),
)
# Out:
# <div class="toyplot" id="t2eccd69e00724038b47900daa280e5c5" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="2000.0px" id="tfb4b3b0d42a94d139d4ff582eaa5dc33" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 2000.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="td51c7d44e6034cd29c8ce2eea5c6fb0d"><clipPath id="t0e45200181384808adb2276683207aa1"><rect height="1940.0" width="440.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t0e45200181384808adb2276683207aa1)"><g class="toytree-mark-Toytree" id="t65d5b98bc0334db6be2b6f9a7bd157fb"><g class="toytree-Edges" style="fill:
# ...

# %%
import toyplot.svg
toyplot.svg.render(canvas05c, "/moto/eaton/users/hnl2109/svg-trees/cal-crown-colors_circle_basic_scaffold05.svg")

# %%
toyplot.svg.render(canvas05c, "/moto/eaton/users/hnl2109/svg-trees/cal-crown_basic_scaffold05.svg")
toyplot.svg.render(canvas05s, "/moto/eaton/users/hnl2109/svg-trees/cal-crown_basic_scaffold05.svg")
